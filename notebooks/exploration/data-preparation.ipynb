# %%
import os
import shutil
import sys
import cv2
sys.path.append('/content/drive/MyDrive/thesis/src')
from segmentation.video import Video

def segment_videos(dataset_path: str):
    # make a copy of the provided folder
    dataset_copy_path = dataset_path + '_copy'
    shutil.copytree(dataset_path, dataset_copy_path)

    # get list of all files and folders within the copy
    items = os.listdir(dataset_copy_path)
    # iterate over items
    for item in items:
        print("=================================================================================")
        print(f"Action: {item}\n")
        # check if item is a folder
        if os.path.isdir(os.path.join(dataset_copy_path, item)):
            # get list of all files and folders within the current folder
            videos = os.listdir(os.path.join(dataset_copy_path, item))
            # iterate over children and print their paths
            for video_name in videos:
                video_path = os.path.join(dataset_copy_path, item, video_name)
                print(video_path)
                video = Video(video_path, K=3)
                segments = video.segments
                
                dir_path = os.path.dirname(video_path)
                new_folder = video_name[:-4]
                new_folder_path = os.path.join(dir_path, new_folder)
                os.makedirs(new_folder_path, exist_ok=True)

                for k in range(video.segments_number):
                    segment = segments[k]
                    random_snippet = segments[k].random_snippet
                    rgb_frame = random_snippet.rgb_frame
                    flow_frame = random_snippet.flow_frame
                    pose_frame = random_snippet.body_pose_frame

                    segment_folder_name = f"segment-{k}"
                    segment_folder_path = os.path.join(new_folder_path, segment_folder_name)
                    os.makedirs(segment_folder_path, exist_ok=True)

                    # ======================================
                    rgb_frame_name = "rgb_frame.png"
                    flow_frame_name = "flow_frame.png"
                    pose_frame_name = "pose_frame.png"

                    rgb_frame_file_path = os.path.join(segment_folder_path, rgb_frame_name)
                    flow_frame_file_path = os.path.join(segment_folder_path, flow_frame_name)
                    pose_frame_file_path = os.path.join(segment_folder_path, pose_frame_name)

                    cv2.imwrite(rgb_frame_file_path, rgb_frame)
                    cv2.imwrite(flow_frame_file_path, flow_frame)
                    cv2.imwrite(pose_frame_file_path, pose_frame)
                    # ======================================
                
                os.remove(video_path) # we remove the .avi video
    
segment_videos('/content/drive/MyDrive/thesis/data/HMDB-51-downsampled')
# Out:
# Downloading model to /usr/local/lib/python3.9/dist-packages/mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite
# =================================================================================
# Action: laugh
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/laugh/Laughing_Girl_laugh_u_nm_np1_ri_goo_3.avi
# total frames 276
# frames_per_segment 92
# start 0 and end 91
# start 0 and end 91
# start 0 and end 90
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/laugh/Glory_laugh_u_nm_np1_fr_bad_19.avi
# total frames 84
# frames_per_segment 28
# start 0 and end 27
# start 0 and end 27
# start 0 and end 26
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/laugh/Laughing_Girl_laugh_u_nm_np1_ri_goo_1.avi
# total frames 467
# frames_per_segment 155
# start 0 and end 154
# start 0 and end 154
# start 0 and end 154
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/laugh/Laughing_for_Skype_laugh_h_cm_np1_fr_goo_2.avi
# total frames 147
# frames_per_segment 49
# start 0 and end 48
# start 0 and end 48
# start 0 and end 47
# =================================================================================
# Action: kiss
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kiss/Hangingbyamomentfavoritekisses_kiss_u_nm_np2_le_goo_3.avi
# total frames 247
# frames_per_segment 82
# start 0 and end 81
# start 0 and end 81
# start 0 and end 81
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kiss/TVs_Best_Kisses_Top_50_(30_to_21)_kiss_h_nm_np2_le_goo_0.avi
# total frames 146
# frames_per_segment 48
# start 0 and end 47
# start 0 and end 47
# start 0 and end 47
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kiss/BestKisses_kiss_h_cm_np2_fr_goo_7.avi
# total frames 96
# frames_per_segment 32
# start 0 and end 31
# start 0 and end 31
# start 0 and end 30
# =================================================================================
# Action: shoot_bow
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_bow/TURKISHRECURVEBOW_shoot_bow_u_cm_np1_ba_med_1.avi
# total frames 126
# frames_per_segment 42
# start 0 and end 41
# start 0 and end 41
# start 0 and end 40
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_bow/TurkishBowAdnan_shoot_bow_u_cm_np1_fr_goo_0.avi
# total frames 101
# frames_per_segment 33
# start 0 and end 32
# start 0 and end 32
# start 0 and end 32
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_bow/6arrowswithin30seconds_shoot_bow_f_nm_np1_fr_med_2.avi
# total frames 82
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 26
# =================================================================================
# Action: fencing
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fencing/Rapier_drills_fencing_f_nm_np2_ri_bad_4.avi
# total frames 58
# frames_per_segment 19
# start 0 and end 18
# start 0 and end 18
# start 0 and end 18
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fencing/The_Scarlet_Pimpernel_-_duel_fencing_u_cm_np2_fr_med_0.avi
# total frames 104
# frames_per_segment 34
# start 0 and end 33
# start 0 and end 33
# start 0 and end 33
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fencing/Rapier_fencing_f_cm_np1_ri_med_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: walk
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/20060723sfjffschmoozer_walk_f_cm_np1_ri_med_1.avi
# total frames 219
# frames_per_segment 73
# start 0 and end 72
# start 0 and end 72
# start 0 and end 71
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/NOVA_ELEGANTUNIVERSE1_walk_u_nm_np1_fr_med_5.avi
# total frames 74
# frames_per_segment 24
# start 0 and end 23
# start 0 and end 23
# start 0 and end 23
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/TheBoondockSaints_walk_u_cm_np1_fr_med_6.avi
# total frames 49
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/AmericanGangster_walk_f_cm_np1_fr_bad_9.avi
# total frames 106
# frames_per_segment 35
# start 0 and end 34
# start 0 and end 34
# start 0 and end 34
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/TheLastManOnearth_walk_f_cm_np1_ri_med_15.avi
# total frames 75
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 23
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/WeddingCrashers_walk_u_cm_np1_ri_med_7.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/20060723sfjffprofessionalhelp_walk_u_nm_np2_le_med_0.avi
# total frames 51
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/TheBoondockSaints_walk_f_nm_np1_fr_med_41.avi
# total frames 54
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 16
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/BIG_FISH_walk_f_nm_np1_ba_med_18.avi
# total frames 85
# frames_per_segment 28
# start 0 and end 27
# start 0 and end 27
# start 0 and end 27
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/The_Fugitive_6_walk_u_cm_np1_ba_med_17.avi
# total frames 120
# frames_per_segment 40
# start 0 and end 39
# start 0 and end 39
# start 0 and end 38
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/TheLittleShopofHorrors_walk_f_cm_np1_fr_med_12.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/Veoh_Alpha_Dog_1_walk_l_nm_np1_ba_med_31.avi
# total frames 87
# frames_per_segment 29
# start 0 and end 28
# start 0 and end 28
# start 0 and end 27
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/Eurotrip_walk_u_cm_np1_fr_med_6.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/A_Beautiful_Mind_4_walk_u_cm_np3_fr_med_12.avi
# total frames 130
# frames_per_segment 43
# start 0 and end 42
# start 0 and end 42
# start 0 and end 42
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/IamLegend_walk_f_nm_np1_fr_med_17.avi
# total frames 104
# frames_per_segment 34
# start 0 and end 33
# start 0 and end 33
# start 0 and end 33
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/walk/AMADEUS_walk_f_nm_np1_fr_med_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: ride_bike
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/ride_bike/Radfahren_um_die_Aggertalsperre_06_09_2009_ride_bike_f_cm_np2_fr_med_15.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/ride_bike/1989_Tour_de_France_Final_Time_Trial_ride_bike_f_cm_np1_ri_med_3.avi
# total frames 62
# frames_per_segment 20
# start 0 and end 19
# start 0 and end 19
# start 0 and end 19
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/ride_bike/Fahrrad_fahren_mit_Albert_ride_bike_f_cm_np1_le_med_2.avi
# total frames 141
# frames_per_segment 47
# start 0 and end 46
# start 0 and end 46
# start 0 and end 45
# =================================================================================
# Action: draw_sword
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/draw_sword/IAIDO_-_Training_TV-Bericht_10_2008_draw_sword_u_nm_np1_fr_med_0.avi
# total frames 53
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 16
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/draw_sword/Eishin_Ryu_Iaido_-_Toho_Forms_draw_sword_f_cm_np1_le_med_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/draw_sword/Tatehiza_draw_sword_f_nm_np1_fr_med_1.avi
# total frames 99
# frames_per_segment 33
# start 0 and end 32
# start 0 and end 32
# start 0 and end 31
# =================================================================================
# Action: hug
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hug/-_FREE_HUGS_-_Abrazos_Gratis_www_abrazosgratis_org_hug_u_cm_np2_ba_goo_2.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hug/American_Idol_Awards_Given_to_7_Winners_at_Walt_Disney_World_hug_u_cm_np2_le_med_4.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hug/Free_Hugs_-_Medellin_hug_f_cm_np2_le_med_0.avi
# total frames 62
# frames_per_segment 20
# start 0 and end 19
# start 0 and end 19
# start 0 and end 19
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hug/Calins_gratuits_a_Paris_-_Free_Hugs_France_-_version_longue_hug_u_cm_np2_le_med_11.avi
# total frames 96
# frames_per_segment 32
# start 0 and end 31
# start 0 and end 31
# start 0 and end 30
# =================================================================================
# Action: pour
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pour/Drink_#18_-_Apple_martini_pour_u_nm_np1_fr_goo_1.avi
# total frames 103
# frames_per_segment 34
# start 0 and end 33
# start 0 and end 33
# start 0 and end 33
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pour/crazy_german_guy_shows_how_do_they_pour_a_wheat_beer_pour_u_cm_np1_fr_goo_1.avi
# total frames 170
# frames_per_segment 56
# start 0 and end 55
# start 0 and end 55
# start 0 and end 55
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pour/New_Orleans__best_cocktails-_Hot_Buttered_Rum_pour_u_nm_np1_fr_med_2.avi
# total frames 133
# frames_per_segment 44
# start 0 and end 43
# start 0 and end 43
# start 0 and end 43
# =================================================================================
# Action: swing_baseball
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/swing_baseball/practicingmybaseballswing2009_swing_baseball_u_cm_np1_fr_med_0.avi
# total frames 102
# frames_per_segment 34
# start 0 and end 33
# start 0 and end 33
# start 0 and end 32
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/swing_baseball/BaseBallSweetSwingsingle_swing_baseball_f_nm_np1_ba_bad_0.avi
# total frames 95
# frames_per_segment 31
# start 0 and end 30
# start 0 and end 30
# start 0 and end 30
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/swing_baseball/Faith_Rewarded_swing_baseball_f_nm_np1_fr_bad_26.avi
# total frames 45
# frames_per_segment 15
# start 0 and end 14
# start 0 and end 14
# start 0 and end 13
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/swing_baseball/hittingofftee2_swing_baseball_f_nm_np1_fr_med_8.avi
# total frames 129
# frames_per_segment 43
# start 0 and end 42
# start 0 and end 42
# start 0 and end 41
# =================================================================================
# Action: climb
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/climb/India_Monkey_King_scales_new_heights_climb_f_cm_np1_ba_med_3.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/climb/Chiara_Kletterwand_climb_f_cm_np1_ba_bad_0.avi
# total frames 106
# frames_per_segment 35
# start 0 and end 34
# start 0 and end 34
# start 0 and end 34
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/climb/Kletter-WM_2005-_Bouldern_Finale_Damen__Vera_Kotasova_(CZE)_climb_f_cm_np1_ba_med_1.avi
# total frames 144
# frames_per_segment 48
# start 0 and end 47
# start 0 and end 47
# start 0 and end 46
# =================================================================================
# Action: ride_horse
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/ride_horse/HorseRiding_ride_horse_f_cm_np1_le_med_2.avi
# total frames 97
# frames_per_segment 32
# start 0 and end 31
# start 0 and end 31
# start 0 and end 31
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/ride_horse/FullyAlive(Request)_ride_horse_f_cm_np1_ri_med_0.avi
# total frames 98
# frames_per_segment 32
# start 0 and end 31
# start 0 and end 31
# start 0 and end 31
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/ride_horse/BethEventingTraingGeorge_ride_horse_f_cm_np1_ri_med_6.avi
# total frames 172
# frames_per_segment 57
# start 0 and end 56
# start 0 and end 56
# start 0 and end 56
# =================================================================================
# Action: punch
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/punch/PracticingBoxingonaDoubleEndBag-LeadRightwithaHook_punch_u_nm_np1_fr_med_1.avi
# total frames 104
# frames_per_segment 34
# start 0 and end 33
# start 0 and end 33
# start 0 and end 33
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/punch/Glory_punch_u_cm_np1_fr_bad_37.avi
# total frames 33
# frames_per_segment 11
# start 0 and end 10
# start 0 and end 10
# start 0 and end 9
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/punch/THE_PROTECTOR_punch_u_cm_np1_fr_med_7.avi
# total frames 43
# frames_per_segment 14
# start 0 and end 13
# start 0 and end 13
# start 0 and end 13
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/punch/BATMAN_BEGINS_punch_h_nm_np1_ba_bad_7.avi
# total frames 48
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 14
# =================================================================================
# Action: shoot_ball
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_ball/ReggieMillerTakesonThreeAverageGuysinaShootout_shoot_ball_u_nm_np1_ba_med_7.avi
# total frames 75
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 23
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_ball/Finding_Forrester_3_shoot_ball_h_nm_np2_le_med_4.avi
# total frames 89
# frames_per_segment 29
# start 0 and end 28
# start 0 and end 28
# start 0 and end 28
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_ball/Clay_sBasketballSkillz_shoot_ball_f_nm_np1_ba_med_3.avi
# total frames 66
# frames_per_segment 22
# start 0 and end 21
# start 0 and end 21
# start 0 and end 20
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_ball/PlayingBasketballGotWater_shoot_ball_f_nm_np1_ba_med_6.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: hit
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hit/Vorschlaghammer__die_Erste_hit_f_cm_np1_ri_bad_1.avi
# total frames 37
# frames_per_segment 12
# start 0 and end 11
# start 0 and end 11
# start 0 and end 11
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hit/Opel_vs_Vorschlaghammer_hit_u_cm_np1_le_bad_1.avi
# total frames 32
# frames_per_segment 10
# start 0 and end 9
# start 0 and end 9
# start 0 and end 9
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hit/schrank_kaput_geschlagen_hit_u_cm_np1_ba_bad_2.avi
# total frames 33
# frames_per_segment 11
# start 0 and end 10
# start 0 and end 10
# start 0 and end 9
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/hit/KUNG_FU_HUSTLE_hit_f_cm_np1_fr_bad_18.avi
# total frames 51
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 15
# =================================================================================
# Action: flic_flac
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/flic_flac/Flick_Flack_Session__ber_den_Hauptmark_Trier_flic_flac_f_cm_np1_fr_bad_0.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/flic_flac/Flic-Flac_-_Illya_Kun_flic_flac_f_cm_np1_le_med_1.avi
# total frames 76
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/flic_flac/JOAKIN_(air_tricks_extreme)_flic_flac_f_cm_np1_ba_bad_2.avi
# total frames 51
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 15
# =================================================================================
# Action: smile
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/smile/YouTube_smiles!_smile_h_cm_np1_fr_bad_37.avi
# total frames 65
# frames_per_segment 21
# start 0 and end 20
# start 0 and end 20
# start 0 and end 20
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/smile/YouTube_smiles!_smile_h_nm_np1_fr_goo_14.avi
# total frames 70
# frames_per_segment 23
# start 0 and end 22
# start 0 and end 22
# start 0 and end 22
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/smile/show_your_smile_-)_smile_h_nm_np1_fr_med_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: pushup
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pushup/Angela_pushup_u_cm_np1_le_med_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pushup/Chest_Muscle_Group_(for_sexy_arms__shoulders__back_and_abs!)_pushup_u_nm_np1_ri_goo_3.avi
# total frames 108
# frames_per_segment 36
# start 0 and end 35
# start 0 and end 35
# start 0 and end 34
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pushup/push-up_or_shut_up_(IXK)_pushup_f_cm_np1_le_med_1.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# =================================================================================
# Action: shake_hands
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shake_hands/Pambos_and_Maria_at_the_Slavi_s_Show_shake_hands_f_cm_np2_le_bad_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shake_hands/Patricia_Arquette_on_Letterman_2007_shake_hands_f_cm_np2_le_med_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shake_hands/RailsConf_09-___Ruby_Heroes_Award_Ceremony__shake_hands_u_cm_np2_ba_med_7.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shake_hands/Prize_Giving_Ceremony_1_shake_hands_f_cm_np1_ri_med_0.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shake_hands/Bush_Shake_Hands_CNN_mov_shake_hands_u_cm_np4_le_med_1.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: throw
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/throw/Compilationknifethrowing_throw_u_nm_np1_ba_med_14.avi
# total frames 156
# frames_per_segment 52
# start 0 and end 51
# start 0 and end 51
# start 0 and end 50
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/throw/ScottKazmir_throw_f_cm_np1_fr_med_0.avi
# total frames 134
# frames_per_segment 44
# start 0 and end 43
# start 0 and end 43
# start 0 and end 43
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/throw/Knifethrowing4knivestogethernospin_throw_f_nm_np1_ri_med_1.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# =================================================================================
# Action: talk
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/talk/prelinger_ControlY1950_talk_h_nm_np1_fr_goo_3.avi
# total frames 241
# frames_per_segment 80
# start 0 and end 79
# start 0 and end 79
# start 0 and end 79
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/talk/Prelinger_ActYourA1949_talk_u_nm_np1_fr_med_6.avi
# total frames 150
# frames_per_segment 50
# start 0 and end 49
# start 0 and end 49
# start 0 and end 48
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/talk/Faith_Rewarded_talk_h_nm_np1_fr_goo_46.avi
# total frames 120
# frames_per_segment 40
# start 0 and end 39
# start 0 and end 39
# start 0 and end 38
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/talk/Italian_Job_2_talk_h_nm_np1_fr_med_3.avi
# total frames 82
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 26
# =================================================================================
# Action: clap
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/clap/Deutscher_Klatsch_-_The_Clap_-_Lexy_clap_f_cm_np2_ba_med_3.avi
# total frames 34
# frames_per_segment 11
# start 0 and end 10
# start 0 and end 10
# start 0 and end 10
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/clap/RE-_Boom_Snap_Clap_clap_u_nm_np1_fr_med_0.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/clap/103_years_old_japanese_woman__Nao_is_clapping_with_piano_music_by_beethoven_clap_u_cm_np1_fr_med_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/clap/Applauding_Abby_clap_u_nm_np1_fr_med_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: dribble
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dribble/Explosive_Guard_Dribbling_Basketball_Workout_(Jason_Otter)_dribble_f_cm_np1_fr_med_1.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dribble/How_to_Improve_Your_Basketball_Skills_-_How_to_Dribble_a_Basketball_Between_the_Legs_dribble_f_cm_np1_fr_med_0.avi
# total frames 58
# frames_per_segment 19
# start 0 and end 18
# start 0 and end 18
# start 0 and end 18
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dribble/Basketball_Dribbling_-_Basketball_Dribbling-_Having_a_Good_Base_dribble_f_cm_np2_ri_med_3.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dribble/JordanWorld_sbest6yearoldBaller_dribble_f_cm_np1_fr_med_9.avi
# total frames 94
# frames_per_segment 31
# start 0 and end 30
# start 0 and end 30
# start 0 and end 30
# =================================================================================
# Action: chew
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/chew/Fun_Chewing_Gum!_chew_h_nm_np2_fr_med_3.avi
# total frames 97
# frames_per_segment 32
# start 0 and end 31
# start 0 and end 31
# start 0 and end 31
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/chew/Sweet_Candy_Bubbles_chew_h_cm_np1_fr_med_2.avi
# total frames 125
# frames_per_segment 41
# start 0 and end 40
# start 0 and end 40
# start 0 and end 40
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/chew/How_to_Do_Basic_Mime_Skills_-_How_to_Mime_Chewing_Gum_chew_h_cm_np1_fr_med_2.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: stand
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/stand/TheBoondockSaints_stand_f_cm_np1_fr_med_59.avi
# total frames 49
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/stand/IamLegend_stand_f_nm_np1_fr_med_20.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/stand/OldSchool_stand_f_nm_np1_fr_med_21.avi
# total frames 48
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 14
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/stand/Crash_stand_u_nm_np1_ri_med_23.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/stand/BRIDGETOTERABITHIA_stand_f_nm_np1_fr_med_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: kick_ball
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick_ball/Britney_Spears_-_Comercial_Pepsi_soccer_kick_ball_f_nm_np1_fr_med_1.avi
# total frames 38
# frames_per_segment 12
# start 0 and end 11
# start 0 and end 11
# start 0 and end 11
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick_ball/Das_Wunder_von_Bern_(Deutschland_2002_2003)_kick_ball_f_cm_np1_ri_goo_3.avi
# total frames 65
# frames_per_segment 21
# start 0 and end 20
# start 0 and end 20
# start 0 and end 20
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick_ball/How_to_Shoot_Penalty_Kicks_kick_ball_f_cm_np1_ba_bad_3.avi
# total frames 36
# frames_per_segment 12
# start 0 and end 11
# start 0 and end 11
# start 0 and end 10
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick_ball/Nike_Soccer_Freestyle_kick_ball_f_cm_np1_ri_med_4.avi
# total frames 58
# frames_per_segment 19
# start 0 and end 18
# start 0 and end 18
# start 0 and end 18
# =================================================================================
# Action: somersault
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/somersault/Liri_beim_Bodenturnen_somersault_f_cm_np1_le_bad_1.avi
# total frames 100
# frames_per_segment 33
# start 0 and end 32
# start 0 and end 32
# start 0 and end 32
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/somersault/Boden-K_r_somersault_f_cm_np1_ri_med_2.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/somersault/Jennis_Bodenk_r_somersault_f_cm_np1_le_med_0.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/somersault/Turnen_Lisa_en_Janine_op_de_Balk_somersault_f_cm_np1_ri_bad_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: catch
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/catch/Torwarttraining_Arminia_Bielefeld_catch_f_cm_np1_ba_med_1.avi
# total frames 37
# frames_per_segment 12
# start 0 and end 11
# start 0 and end 11
# start 0 and end 11
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/catch/torwart_de-Camp_2009-_Training_hoher_B_lle_mit_Airbodies_catch_f_cm_np1_ba_bad_1.avi
# total frames 41
# frames_per_segment 13
# start 0 and end 12
# start 0 and end 12
# start 0 and end 12
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/catch/torwart_de-Camp_2009_-_Hohe_B_lle_catch_f_cm_np1_ba_med_0.avi
# total frames 62
# frames_per_segment 20
# start 0 and end 19
# start 0 and end 19
# start 0 and end 19
# =================================================================================
# Action: handstand
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/handstand/doppel_handstand_handstand_f_cm_np2_ba_med_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/handstand/handstands_1_handstand_f_cm_np1_le_med_3.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/handstand/hand_stand_handstand_f_cm_np1_ba_med_2.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: push
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/push/Pushing_train_-_Me_and_my_friend_-_Worlds_strongest_men_push_f_cm_np2_ba_bad_4.avi
# total frames 109
# frames_per_segment 36
# start 0 and end 35
# start 0 and end 35
# start 0 and end 35
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/push/Alexander_pushing_the_table_push_f_cm_np1_le_bad_0.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/push/Big_Bebe_walking_and_pushing_her_lion_in_a_box!_push_f_cm_np1_ba_bad_1.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: fall_floor
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fall_floor/BLACK_HAWK_DOWN_fall_floor_f_cm_np1_ri_med_13.avi
# total frames 55
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 17
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fall_floor/KUNG_FU_HUSTLE_fall_floor_f_cm_np1_ba_bad_21.avi
# total frames 54
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 16
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fall_floor/THE_PROTECTOR_fall_floor_f_cm_np1_fr_bad_41.avi
# total frames 48
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 14
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/fall_floor/Veoh_Alpha_Dog_1_fall_floor_f_cm_np1_fr_med_35.avi
# total frames 74
# frames_per_segment 24
# start 0 and end 23
# start 0 and end 23
# start 0 and end 23
# =================================================================================
# Action: turn
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/Oceans12_turn_h_nm_np1_fr_med_11.avi
# total frames 77
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/310ToYuma_turn_h_nm_np1_ba_med_1.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/TheLittleShopofHorrors_turn_h_nm_np1_fr_med_11.avi
# total frames 76
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/The_Fugitive_2_turn_u_nm_np1_ba_goo_18.avi
# total frames 55
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 17
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/OldSchool_turn_f_nm_np1_fr_med_22.avi
# total frames 49
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/KUNG_FU_HUSTLE_turn_u_cm_np1_ri_med_48.avi
# total frames 51
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/turn/Italian_Job_5_turn_u_nm_np1_ba_med_0.avi
# total frames 51
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 15
# =================================================================================
# Action: climb_stairs
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/climb_stairs/treppensteigen_1_climb_stairs_f_cm_np2_fr_med_1.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/climb_stairs/Stadium_Plyometric_Workout_climb_stairs_l_cm_np1_ba_med_4.avi
# total frames 37
# frames_per_segment 12
# start 0 and end 11
# start 0 and end 11
# start 0 and end 11
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/climb_stairs/Piano_stairs__-_TheFunTheory_com_-_Rolighetsteorin_se_climb_stairs_f_nm_np2_fr_med_4.avi
# total frames 76
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# =================================================================================
# Action: pullup
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pullup/30_(dead-hang)_pull-ups_pullup_u_cm_np1_ba_med_1.avi
# total frames 82
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 26
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pullup/Pull-ups_+_Push_ups-_a_time-saving_workout_pullup_u_cm_np1_ri_med_2.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pullup/35_pull_ups_pullup_f_nm_np1_fr_goo_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: brush_hair
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/brush_hair/Brushing_my_waist_lenth_hair_brush_hair_u_nm_np1_ba_goo_0.avi
# total frames 222
# frames_per_segment 74
# start 0 and end 73
# start 0 and end 73
# start 0 and end 72
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/brush_hair/Ella_brushing_her_long_blonde_hair___again_brush_hair_u_cm_np1_le_goo_1.avi
# total frames 305
# frames_per_segment 101
# start 0 and end 100
# start 0 and end 100
# start 0 and end 100
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/brush_hair/Ella_brushing_her_amazing_long_hair_brush_hair_u_cm_np1_ba_goo_0.avi
# total frames 129
# frames_per_segment 43
# start 0 and end 42
# start 0 and end 42
# start 0 and end 41
# =================================================================================
# Action: kick
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick/KUNG_FU_HUSTLE_kick_u_cm_np1_fr_med_11.avi
# total frames 47
# frames_per_segment 15
# start 0 and end 14
# start 0 and end 14
# start 0 and end 14
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick/THE_PROTECTOR_kick_f_nm_np1_fr_med_3.avi
# total frames 47
# frames_per_segment 15
# start 0 and end 14
# start 0 and end 14
# start 0 and end 14
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick/Veoh_Alpha_Dog_1_kick_f_nm_np1_ri_med_50.avi
# total frames 48
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 14
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/kick/The_Matrix_5_kick_f_cm_np1_fr_med_19.avi
# total frames 51
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 15
# =================================================================================
# Action: sword
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword/MAF_Tenshin_Ryu_sword_f_cm_np2_le_med_1.avi
# total frames 95
# frames_per_segment 31
# start 0 and end 30
# start 0 and end 30
# start 0 and end 30
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword/Black_Knight_sword_u_cm_np2_ba_goo_2.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword/Duncan_Macleod_&_Amanda_Soulmates_Part_2_sword_u_cm_np2_fr_med_0.avi
# total frames 272
# frames_per_segment 90
# start 0 and end 89
# start 0 and end 89
# start 0 and end 89
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword/Medieval_Times_Knights_Battle_Sword_Fight_sword_f_cm_np2_fr_med_5.avi
# total frames 62
# frames_per_segment 20
# start 0 and end 19
# start 0 and end 19
# start 0 and end 19
# =================================================================================
# Action: sit
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sit/American_History_X_sit_f_nm_np1_fr_med_24.avi
# total frames 64
# frames_per_segment 21
# start 0 and end 20
# start 0 and end 20
# start 0 and end 20
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sit/Pirates_5_sit_f_nm_np1_fr_med_11.avi
# total frames 73
# frames_per_segment 24
# start 0 and end 23
# start 0 and end 23
# start 0 and end 23
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sit/IamLegendII_sit_f_cm_np1_fr_med_7.avi
# total frames 203
# frames_per_segment 67
# start 0 and end 66
# start 0 and end 66
# start 0 and end 66
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sit/Eurotrip_sit_u_nm_np1_fr_goo_3.avi
# total frames 169
# frames_per_segment 56
# start 0 and end 55
# start 0 and end 55
# start 0 and end 55
# =================================================================================
# Action: shoot_gun
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_gun/The_Matrix_5_shoot_gun_h_cm_np1_fr_goo_5.avi
# total frames 54
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 16
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_gun/The_Matrix_4_shoot_gun_u_nm_np2_fr_goo_2.avi
# total frames 59
# frames_per_segment 19
# start 0 and end 18
# start 0 and end 18
# start 0 and end 18
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/shoot_gun/FirearmsTraining_shoot_gun_u_nm_np1_ri_goo_6.avi
# total frames 175
# frames_per_segment 58
# start 0 and end 57
# start 0 and end 57
# start 0 and end 57
# =================================================================================
# Action: smoke
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/smoke/more_smoking_smoke_h_cm_np1_ri_med_1.avi
# total frames 138
# frames_per_segment 46
# start 0 and end 45
# start 0 and end 45
# start 0 and end 44
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/smoke/smoking_smoke_h_nm_np1_fr_med_2.avi
# total frames 195
# frames_per_segment 65
# start 0 and end 64
# start 0 and end 64
# start 0 and end 63
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/smoke/smoking_1_smoke_h_cm_np1_ri_med_2.avi
# total frames 150
# frames_per_segment 50
# start 0 and end 49
# start 0 and end 49
# start 0 and end 48
# =================================================================================
# Action: golf
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/golf/Iain_Powell_Driving_at_Ingon_Manor_GC_golf_f_cm_np1_ri_med_0.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/golf/Na_Yeon_Choi_practice_1_golf_f_nm_np1_ri_goo_1.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/golf/Paula_Creamer_golf_f_cm_np1_ri_med_0.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# =================================================================================
# Action: eat
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/eat/CharlieAndTheChocolateFactory_eat_u_nm_np1_fr_goo_22.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/eat/THE_PROTECTOR_eat_u_nm_np1_le_goo_59.avi
# total frames 78
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/eat/MeettheParents_eat_u_nm_np1_fr_med_2.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# =================================================================================
# Action: sword_exercise
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword_exercise/Kendo_Basics_sword_exercise_f_cm_np1_le_bad_2.avi
# total frames 68
# frames_per_segment 22
# start 0 and end 21
# start 0 and end 21
# start 0 and end 21
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword_exercise/Highlander_I_with_Christophe_Lambert_&_Sean_Connery_sword_exercise_f_cm_np2_ba_bad_0.avi
# total frames 133
# frames_per_segment 44
# start 0 and end 43
# start 0 and end 43
# start 0 and end 43
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword_exercise/Eishin-Ryu_Iaido_sword_exercise_f_cm_np1_ri_bad_4.avi
# total frames 49
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/sword_exercise/Eishin-Ryu_Iaido_sword_exercise_f_cm_np1_fr_bad_11.avi
# total frames 59
# frames_per_segment 19
# start 0 and end 18
# start 0 and end 18
# start 0 and end 18
# =================================================================================
# Action: run
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/BRIDGETOTERABITHIA_run_f_nm_np1_le_med_6.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/BLACK_HAWK_DOWN_run_f_cm_np1_le_med_18.avi
# total frames 49
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/likebeckam_run_f_cm_np1_ba_med_22.avi
# total frames 50
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/AmericanGangster_run_u_cm_np1_ri_med_65.avi
# total frames 46
# frames_per_segment 15
# start 0 and end 14
# start 0 and end 14
# start 0 and end 14
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/CharlieAndTheChocolateFactory_run_f_nm_np1_fr_med_24.avi
# total frames 25
# frames_per_segment 8
# start 0 and end 7
# start 0 and end 7
# start 0 and end 7
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/IamLegend_run_f_nm_np1_fr_med_13.avi
# total frames 45
# frames_per_segment 15
# start 0 and end 14
# start 0 and end 14
# start 0 and end 13
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/run/RATRACE_run_f_cm_np1_ba_med_22.avi
# total frames 49
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 15
# =================================================================================
# Action: dive
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dive/BeforeNightFalls_dive_f_cm_np1_ri_bad_1.avi
# total frames 77
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dive/Bungee_Jumping_in_Switzerland_-__Compilation_Part_2_dive_f_cm_np1_fr_bad_1.avi
# total frames 53
# frames_per_segment 17
# start 0 and end 16
# start 0 and end 16
# start 0 and end 16
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dive/K_pfer_dive_f_cm_np1_fr_bad_0.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/dive/Bungee_Jump_-_Shit_dive_u_cm_np1_ba_bad_0.avi
# total frames 55
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 17
# =================================================================================
# Action: situp
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/situp/How_to_Do_Proper_Situps_situp_f_cm_np1_le_goo_0.avi
# total frames 77
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/situp/Ninja_Warrior_Ultimate_Six_Pack_Abs_Sit_up_Training_situp_f_nm_np1_ri_med_1.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/situp/Britney_Spears__Ab_Workout_Revealed_Video_situp_f_cm_np1_ri_goo_0.avi
# total frames 128
# frames_per_segment 42
# start 0 and end 41
# start 0 and end 41
# start 0 and end 41
# =================================================================================
# Action: drink
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/drink/GoneBabyGone_drink_u_cm_np1_le_med_2.avi
# total frames 79
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/drink/Hitch_Part_2_drink_h_nm_np1_le_goo_5.avi
# total frames 54
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 16
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/drink/Veoh_Alpha_Dog_2_drink_u_nm_np1_fr_goo_5.avi
# total frames 135
# frames_per_segment 45
# start 0 and end 44
# start 0 and end 44
# start 0 and end 43
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/drink/CastAway1_drink_h_cm_np1_le_goo_17.avi
# total frames 235
# frames_per_segment 78
# start 0 and end 77
# start 0 and end 77
# start 0 and end 77
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/drink/EVOLUTION_drink_u_cm_np1_fr_goo_11.avi
# total frames 84
# frames_per_segment 28
# start 0 and end 27
# start 0 and end 27
# start 0 and end 26
# =================================================================================
# Action: wave
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/wave/Maddin_winkt_wave_h_cm_np1_le_med_0.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/wave/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_1.avi
# total frames 80
# frames_per_segment 26
# start 0 and end 25
# start 0 and end 25
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/wave/DONNIE_DARKO_wave_u_nm_np1_le_goo_8.avi
# total frames 106
# frames_per_segment 35
# start 0 and end 34
# start 0 and end 34
# start 0 and end 34
# =================================================================================
# Action: cartwheel
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/cartwheel/Monikas_Staatsexamen__Turnen_cartwheel_f_cm_np1_ri_med_4.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/cartwheel/lea_kann_radschlag_cartwheel_f_cm_np1_ri_med_0.avi
# total frames 91
# frames_per_segment 30
# start 0 and end 29
# start 0 and end 29
# start 0 and end 29
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/cartwheel/Bodenturnen_2004_cartwheel_f_cm_np1_le_med_0.avi
# total frames 41
# frames_per_segment 13
# start 0 and end 12
# start 0 and end 12
# start 0 and end 12
# =================================================================================
# Action: pick
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pick/TheBigBangS01E02TheBigBranHypothesis_pick_u_cm_np1_le_med_1.avi
# total frames 81
# frames_per_segment 27
# start 0 and end 26
# start 0 and end 26
# start 0 and end 25
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pick/americanthrift1_pick_u_cm_np1_fr_med_1.avi
# total frames 77
# frames_per_segment 25
# start 0 and end 24
# start 0 and end 24
# start 0 and end 24
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/pick/#122_Cleaning_Up_The_Beach_In_Chiba__Japan_pick_f_nm_np1_ri_bad_0.avi
# total frames 70
# frames_per_segment 23
# start 0 and end 22
# start 0 and end 22
# start 0 and end 22
# =================================================================================
# Action: jump
#
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/jump/Arrasando_no_Le_Parkour_jump_f_nm_np1_ri_med_3.avi
# total frames 55
# frames_per_segment 18
# start 0 and end 17
# start 0 and end 17
# start 0 and end 17
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/jump/THE_PROTECTOR_jump_f_cm_np1_ba_bad_30.avi
# total frames 45
# frames_per_segment 15
# start 0 and end 14
# start 0 and end 14
# start 0 and end 13
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/jump/Faith_Rewarded_jump_f_nm_np1_ri_med_89.avi
# total frames 103
# frames_per_segment 34
# start 0 and end 33
# start 0 and end 33
# start 0 and end 33
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/jump/Two_Towers_6_jump_f_nm_np1_le_bad_9.avi
# total frames 43
# frames_per_segment 14
# start 0 and end 13
# start 0 and end 13
# start 0 and end 13
# /content/drive/MyDrive/thesis/data/HMDB-51-downsampled_copy/jump/BATMAN_BEGINS_jump_f_cm_np1_ri_med_18.avi
# total frames 48
# frames_per_segment 16
# start 0 and end 15
# start 0 and end 15
# start 0 and end 14

# %%
video = Video("/content/drive/MyDrive/thesis/data/HMDB-51-downsampled/cartwheel/Monikas_Staatsexamen__Turnen_cartwheel_f_cm_np1_ri_med_4.avi", K=3)
segments = video.segments
random_snippet = segments[0].random_snippet

# %%
random_snippet.display_rgb_frame()

# %%
random_snippet.display_optical_flow_frame()
# Out:
# /usr/local/lib/python3.9/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
random_snippet.display_body_pose_frame()
